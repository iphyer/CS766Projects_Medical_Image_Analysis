# %%
import matplotlib.pyplot as plt

# %%
loss = []
with open('lossCurve.txt') as f:
    content = f.readlines()

for i in range(len(content)):
    loss.append(float(content[i].split()[-1]))

# %%
#print(loss)
plt.plot(loss)
plt.show()

# %%
print(loss)
# Out:
# ['26.2653', '71.3739', '592.3572', '473.5901', '396.5043', '349.1749', '323.6494', '294.4132', '270.0089', '252.2481', '233.1476', '216.3507', '201.9494', '189.3475', '178.4315', '168.6144', '159.5243', '152.0486', '144.6596', '137.8978', '131.8252', '126.3039', '121.2638', '116.6146', '112.3333', '108.4099', '104.7637', '101.4330', '98.3642', '8.8698', '9.3934', '9.6072', '9.5995', '9.3141', '9.1418', '9.1603', '9.0984', '8.9894', '8.8779', '8.8627', '8.7756', '8.8233', '8.9727', '8.9837', '8.9493', '8.9314', '8.8549', '8.8307', '8.8317', '8.8507', '8.8158', '8.8015', '8.7587', '8.6949', '8.6688', '8.6372', '8.6212', '8.6065', '9.5536', '8.9605', '8.4990', '8.3461', '8.3625', '8.3048', '8.1644', '8.2537', '8.3532', '8.3054', '8.2442', '8.1817', '8.1179', '8.0878', '8.1434', '8.1087', '8.1149', '8.1007', '8.1145', '8.0928', '8.0566', '8.0011', '7.9775', '7.9855', '7.9635', '7.9633', '7.9609', '7.9447', '7.9201', '7.7236', '7.7275', '7.6989', '7.7907', '7.8441', '7.7664', '7.9051', '7
# ...
